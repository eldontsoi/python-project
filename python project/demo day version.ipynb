# %%
#modules and functions
#have to twice to get the code running, no idea why

#import modules
import pandas as pd
import wikipedia
import numpy as np
from IPython.display import display # this isnot the issue that's displaying all the map pins 
import dateutil #useless, convert date to a date
import matplotlib.pyplot as plt
import folium
import random 
from geopy.geocoders import Nominatim #always create timeout error -v- idky
geolocator = Nominatim()
import warnings
warnings.filterwarnings('ignore')
from gtts import gTTS #google text to speech
from time import sleep #hault the tts fx
import time
import pyglet #speech to text 
import os    
import subprocess 
from gtts import gTTS
map = folium.Map(zoom_start=3)
import speech_recognition as sr
from IPython.display import display, HTML
import matplotlib.pyplot as plt; plt.rcdefaults()
import webbrowser
from IPython.display import Image
from IPython.core.interactiveshell import InteractiveShell #this might be the problem 
InteractiveShell.ast_node_interactivity = "all"
import json
import requests


###functions###
#text to audio
def talk(text):
    audio_file = "hello.mp3"
    tts = gTTS(text, lang="en-uk")
    tts.save(audio_file)
    return_code = subprocess.call(["afplay", audio_file])

#text = input('text: ')
#talk(text)
#functions

#google map api

def google_map (city):
    api_key = 'AIzaSyADdu88Rv6sqwPXjuTG_ciKUiZx7WhFei8'
    googlekey = api_key
    #location = 'Syracuse, NY'
    url = 'https://maps.googleapis.com/maps/api/geocode/json'
    params = { 'key': googlekey, 'address': city}
    response = requests.get(url, params=params)
    if response.ok:
        geodata = response.json()
        coords = geodata['results'][0]['geometry']['location']
        gmap_address = coords['lat'],coords['lng']
        #print(coords)
    return gmap_address

#website function
def web_request (driver):
    
    driver_website_dict ={'lewis': 'http://www.4mula1.ro/s/?cdx=4d2ac0e&poi=1&idd=924',
                          'alonso':'http://www.4mula1.ro/s/?cdx=f17791c&idd=884',
                         'vettel':'http://www.4mula1.ro/s/?cdx=b23415a&idd=927',
                         'kimi': 'http://www.4mula1.ro/s/?cdx=bde10b8&idd=881',
                          'battle':'http://www.4mula1.ro/s/?cdx=b23415a&idd=927',
                          'Roseburg':'http://www.4mula1.ro/s/?cdx=dea2918&idd=919',
                          'timmy' : 'http://www.4mula1.ro/s/?cdx=bde10b8&idd=881',
                         'rosberg':'http://www.4mula1.ro/s/?cdx=dea2918&idd=919',
                         'nico':'http://www.4mula1.ro/s/?cdx=dea2918&idd=919'}
    driver_website_dict[driver]
    return driver_website_dict[driver]

#plot graph

def plot_graph (driver):
    plt.plot(['2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017'],
             [total2007,total2008,total2009,total2010,total2011,total2012,total2013,total2014,total2015,total2016,total2017])
    plt.title(driver+"'s points from year 2007 to 2017")
    plt.ylabel('Points')
    plt.xlabel('Year')
    
    return plt.show()
#filter year funciton
#how can i shrink these lines? groupby? :((((
def filter_year (df):
    f1Data2007 = df[df[1].str[:4]=='2007'] 
    f1Data2008 = df[df[1].str[:4]=='2008'] 
    f1Data2009 = df[df[1].str[:4]=='2009'] 
    f1Data2010 = df[df[1].str[:4]=='2010']
    f1Data2011 = df[df[1].str[:4]=='2011']
    f1Data2012 = df[df[1].str[:4]=='2012']
    f1Data2013 = df[df[1].str[:4]=='2013']
    f1Data2014 = df[df[1].str[:4]=='2014']
    f1Data2015 = df[df[1].str[:4]=='2015']
    f1Data2016 = df[df[1].str[:4]=='2016']
    f1Data2017 = df[df[1].str[:4]=='2017']
    return True

#total points calculator not working funciton
def total_points_calulator ():
    #make a function do int conversion
    total2007 = 0
    total2008 = 0
    total2009 = 0
    total2010 = 0
    for items in f1Data2007[7]:
        total2007 = total2007 + float(items)
    for items in f1Data2008[7]:
        total2008 = total2008 + float(items)
    for items in f1Data2010[7]:
        total2009 = total2009 + float(items)
    for items in f1Data2010[7]:
        total2010 = total2010 + float(items)
    total2011 = 0
    for items in f1Data2011[7]:
        total2011 = total2011 + float(items)
    total2012 = 0
    for items in f1Data2012[7]:
        total2012 = total2012 + float(items)
    total2013 =0
    for items in f1Data2013[7]:
        total2013 = total2013 + float(items)
    total2014 = 0
    for items in f1Data2014[7]:
        total2014 = total2014 + float(items)
    total2015 = 0
    for items in f1Data2015[7]:
        total2015 = total2015 + float(items)
    total2016 = 0
    for items in f1Data2016[7]:
        total2016 = total2016 + float(items)
    total2017 = 0
    for items in f1Data2017[7]:
        total2017 = total2017 + float(items)
    return True
#location fider function convert city name to location coordinates
def location_finder (city_list):
    for city in city_list:
        location = geolocator.geocode(city)
        location.address
        location_address = location.address.split(',')
        location_address = location_address[0]
        location_coord = location.latitude, location.longitude
    return(location_address)

#audio to text
def audioFile():
    with sr.Microphone(device_index = 0) as source: #device 0 is mac  1 2 3 either one c
        r.energy_threshold = 4000 #
        audio = r.listen(source,timeout=4.5)
    return audio
r = sr.Recognizer()

#def please_try_again (driver_no):
    
#r.recognize_google(audioFile())

#color code function

def color_html (html_color, html_object):
    display(HTML("<span style = 'color: %s;'>%s"%(html_color,html_object)))
    
#how to change color of individual bar
#speak function
def speak (): #speak audio file
    response = r.recognize_google(audioFile())
    return response
#response = speak()
#print(response)
#speech dont understand function, bad input
def talk_bad ():
    talk_cant_understand = "I'm so sorry I didn't quite get that. please speak clearly."
    return talk_cant_understand
#color_html('red',talk_bad())
#talk(talk_bad())
#print graph function #funfact about teams

def team_graph(): #version 2 will do a list of fun facts and random choice one
    color_html("DarkRed","The fun fact is despite Ferrari has the most victories, they have been in a championship drought for more than 10 years!")
    talk("The fun fact is despite Ferrari has the most victories, they have been in a championship drought for more than 10 years!")
    objects = ('Ferrari', 'McLaren', 'Mercedes', 'Williams', 'Lotus', 'Red Bull')
    y_pos = np.arange(len(objects))
    performance = [96,73,52,46,38,30]

    plt.bar(y_pos, performance, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('Number of Wins')
    plt.title('Number of Cumalative Victories For each Team from 1950 to 2018')
     #ax.legend()
    return plt.show()

def driver_icon (driver): #display driver pic 
    driver_pic = Image(filename= driver+'.jpg')
    return driver_pic

from geopy.exc import GeocoderTimedOut
#actual code
#f1Data['Date'] = f1Data[1].apply(dateutil.parser.parse, dayfirst=False)
from IPython.display import display
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
color_html('lightblue',"Hi I am FormulaSmart! Your personal sport assistant. I can answer your inquiries about Formula 1! ")
talk("Hi I am FormulaSmart! Your personal sport assistant. I can answer your inquiries about Formula 1! Here is a picture of one of my best friends!")
Image(filename='Lewis_Hamilton_2017_Malaysia_FP2.jpg')
color_html('Aquamarine',"And here are my founders! They are, from top to botom, Eldon, Ciara, and Steve.")
talk("And here are my founders! They are, from top to botom, Eldon, Ciara, and Steve.")
Image(filename='eldon.jpg')
color_html('Aquamarine',"Eldon is a freshman")
talk("Eldon is a freshman")
Image(filename='ciara.jpeg')
color_html('Aquamarine',"Ciara is a sophomore.")
talk("Kiara is a sophomore")
Image(filename='steve.jpeg')
color_html('Aquamarine',"Steve is a junior, and they are all studying in the School of Information Studies, majoring in Information Management and Technology.")
talk("Steve is a junior, and they are all studying in the School of Information Studies, majoring in Information Management and Technology.")


#Image(filename='eldon.jpg')


#Image(filename='ciara.jpeg')

color_html('Aquamarine',"They are so awesome and I am very fortunate to be created by three young talented coders!")
#Image(filename='steve.jpeg')
talk("They are so awesome and I am very fortunate to be created by three young talented coders! Thank you so much to Eldon, Kiara, and Steve")

talk("Below is the instruction of running this code:")
color_html("red","this program requires a two way interaction. Formula Assistant will indicate you to speak by displaying the following lines")
color_html("Aquamarine","Your FormulaSmart Assistant is listening...")
color_html("red","please speak within 5 seconds when the program displays the above instruction. Thank you and enjoy!")

input("Press enter to continue ")
while True:
    try:
        #def youtube_search (speak_function) fail:
        color_html("lightblue","I am so excited to meet you. What is your name?")
        talk("I am so excited to meet you. What is your name?")
        color_html('Aquamarine',"Your FormulaSmart Assistant is listening...")
        user_name = speak().lower()
        #try to eliminate possible cofusion for the word 'Avi'
        if user_name == 'lobby' or user_name == 'hobby' or user_name == 'bobby' or user_name == 'bobby': 
            user_name == 'Avi'
        
        color_html('lightblue',"It's so nice to meet you, %s . Let's start off by searching some Formula 1 related youtube videos! What would you like to search about?e.g. f1 2018 australia highlights"%(user_name))
        break
    except:
        talk(talk_bad())#timeout error
        user_name = input("It's okay you can type in your name: ")
        break
try:        
    talk("It's so nice to meet you, %s. let's start off by searching some Formula 1 related youtube videos! What would you like to search about?   "%(user_name))
    color_html('Aquamarine',"Your FormulaSmart Assistant is listening...")
    youtube_response = "https://www.youtube.com/results?search_query="+speak().replace(" ",",")
    #YT_response_wif_pic = "http://img.youtube.com/vi/<"+youtube_response+">/maxresdefault.jpg"
    #url = 'http://www.python.org/'

    # Open URL in a new tab, if a browser window is already open.
    webbrowser.open_new_tab(youtube_response)
    #break
#youtube_search(speak())

except:
    talk(talk_bad())

start_program = input("press enter to continue ")

while True:
    try:
        
        color_html('lightblue',"%s , do you want to know a fun fact about formula 1? Please answer yes or no"%(user_name))
        talk("%s , do you want to know a fun fact about formula 1?"%(user_name))
        color_html('Aquamarine',"Your FormulaSmart Assistant is listening...")
        team_response = speak()
        if team_response == 'yeah' or team_response == 'yes' or team_response == 'mmhumm' or team_response == 'yup':

            team_graph()
            color_html('lightblue','above is a graph of how Ferrari did compared to the top 5 teams in Formula 1 history')
            talk("above is a graph of how Ferrari did compared to the top 5 teams in Formula 1 history")
            break
        if team_response == 'nah' or team_response ==  'no' or team_response == 'nope': 
            color_html("lightblue","it's okay let's move on to something else")
            talk("it's okay let's move on to something else")
            break
    except:
        color_html('red',talk_bad())
        talk(talk_bad())
        team_response = input("Perhaps you should type in your input: ")
        break
        #continue

color_html("lightblue","Do you know what is formula 1? please answer yes or no ")
talk("%s Do you know what is formula 1? please answer yes or no "%(user_name))
while True:
    try:
        color_html('Aquamarine',"Your FormulaSmart Assistant is listening...")
        response = speak().lower()
        if response == 'yes' or response == 'no' :
            break
        
    except:
        color_html('red',talk_bad())
        talk(talk_bad())
        team_response = input("Perhaps you should type in your input: ")
        break

try:
    if response == 'yes':
        color_html("blue","Ok that's perfect. Let me show you the most successful drivers in the past 5 years: Lewis, Rosberg, Vettel,Alonso, and Kimi  ")

        text = "Ok that's perfect. Let me show you the best drivers in formula 1 recent history! Please say the driver name you want to know more about. you can choose lewis, rosberg, vettel,alonso, and kimi "
        talk(text)
        while True:
            try:
                color_html('Aquamarine',"Your FormulaSmart Assistant is listening...")
                driver= speak().lower()#input("who is your favorite driver?") 
                if driver == 'timmy' or driver == 'roseburg' or driver == 'battle': # or driver == 'timmy' or
                    if driver == 'timmy':
                        driver == 'kimi'
                    if driver == 'roseburg':
                        driver == 'rosberg'
                    if driver == 'battle':
                        driver == 'vettel'
                #print("I think you said %s"%(driver_speaker))
            #talk("You chose %s"%(driver))
            #if driver == 'lewis' or driver == 'rosberg' or driver == 'vettel' or driver == 'alonso' or driver == 'kimi'or driver == 'roseburg' or driver == 'timmy' or driver == 'battle':

            #bug #fixed
            #dunno why keep showing vettel
            #fix it tmr lol
                #driver = ''
                driver_pic = ''
                if driver == 'lewis':
                    driver = 'lewis'
                    color_html("lightblue","Here is a picture of %s and a summary of him."%(driver))
                    talk("Here is a picture of %s and a summary of him. "%(driver))
                    driver_icon(driver)
                    talk("Isn't he handsome?")
                    break
                if driver == 'battle' or driver =='vettel':
                    driver = 'vettel'
                    driver_pic = Image(filename='vettel.jpg')
                    color_html("lightblue","Here is a picture of %s and a summary of him."%(driver))
                    talk("Here is a picture of %s and a summary of him"%(driver))
                    driver_pic
                    talk("Isn't he handsome?")
                    break
                if driver == 'roseburg' or driver == 'rosberg':
                    driver = 'rosberg'

                    color_html("lightblue","Here's is a picture of %s and a summary of him."%(driver))
                    talk("Here is a picture of %s and a summary of him."%(driver))
                    driver_icon(driver)
                    talk("Isn't he handsome?")
                    break


                if driver == 'timmy' or driver =='kimi' or driver =='kimmy':
                    driver = 'kimi'

                    color_html("lightblue","Here is a picture of %s and a summary of him."%(driver))
                    talk("Here is a picture of %s and a summary of him."%(driver))
                    driver_icon(driver)
                    talk("Isn't he handsome?")
                    break

                if driver == 'alonzo' or driver =='alonso':
                    driver = 'alonso'

                    color_html("lightblue","Here is a picture of %s and a summary of him."%(driver))
                    #talk("Here's is a picture of %s and a summary of him. Isn't he handsome?"%(driver))
                    driver_icon(driver)
                    talk("Isn't he handsome?")
                    break#
                else:
                    talk(talk_bad())
                    #else:
                     #   color_html('red',talk_bad())
                  #  talk(talk_bad())
            except:
                color_html('red',talk_bad())
                talk(talk_bad())
                driver = input("Perhaps you should type in your input: ")
                break
    if response =='no':
        color_html("blue","Let me tell you more about formula 1. Below is an excerpt from Wikipedia.")
        talk("Let me tell you more about formula 1. Below is an excerpt from Wikipedia.")
        wiki_stuff = wikipedia.summary("Formula 1")
        color_html("cadetblue","%s"%(wiki_stuff))
        talk("Here is a summary of Formula 1, please enjoy. For your reference, the next race starts this weekend! I am so excited about it.")
        #color_html("blue","here are the most successful drivers in the past 5 years: Lewis, Nico Rosberg, Vettel,Alonso, and Kimi  ")
        
        color_html('lightblue',"Which driver do you want to know more about? Please say in his name. you can choose lewis,rosberg, vettel,alonso, and kimi ")
        text = "Which driver do you want to know more about? Please type in his name. you can choose lewis,rosberg, vettel,alonso, and kimi "
        talk(text)
        count = 0
        while True:
            try:
                color_html('Aquamarine',"Your FormulaSmart Assistant is listening...")
                driver= speak().lower()#input("who is your favorite driver?") 
                if driver == 'timmy' or driver == 'roseburg' or driver == 'battle': # or driver == 'timmy' or
                    if driver == 'timmy':
                        driver == 'kimi'
                    if driver == 'roseburg':
                        driver == 'rosberg'
                    if driver == 'battle':
                        driver == 'vettel'
                #print("I think you said %s"%(driver_speaker))
            #talk("You chose %s"%(driver))
            #if driver == 'lewis' or driver == 'rosberg' or driver == 'vettel' or driver == 'alonso' or driver == 'kimi'or driver == 'roseburg' or driver == 'timmy' or driver == 'battle':

            #bug #fixed
            #dunno why keep showing vettel
            #fix it tmr lol
                #driver = ''
                driver_pic = ''
                if driver == 'lewis':
                    driver = 'lewis'
                    color_html("lightblue","Here is a picture of %s and a summary of him."%(driver))
                    talk("Here is a picture of %s and a summary of him"%(driver))
                    driver_icon(driver)
                    talk("Isn't he handsome?")
                    break
                if driver == 'battle' or driver =='vettel': #catch bad pronounciations
                    driver = 'vettel'

                    color_html("lightblue","Here is a picture of %s and a summary of him."%(driver))
                    talk("Here is a picture of %s and a summary of him."%(driver))
                    driver_icon(driver)
                    talk("Isn't he handsome?")
                    break
                if driver == 'roseburg' or driver == 'rosberg':
                    driver = 'rosberg'

                    color_html("lightblue","Here's is a picture of %s and a summary of him."%(driver))
                    talk("Here is a picture of %s and a summary of him."%(driver))
                    driver_icon(driver)
                    talk("Isn't he handsome?")
                    break


                if driver == 'timmy' or driver =='kimi' or driver =='kimmy': #catching bad pronounciations
                    driver = 'kimi'

                    color_html("lightblue","Here is a picture of %s and a summary of him."%(driver))
                    talk("Here is a picture of %s and a summary of him"%(driver))
                    driver_icon(driver)
                    talk("Isn't he handsome?")
                    break

                if driver == 'alonzo' or driver =='alonso':
                    driver = 'alonso'

                    color_html("lightblue","Here is a picture of %s and a summary of him."%(driver))
                    talk("Here's is a picture of %s and a summary of him."%(driver))
                    driver_icon(driver)
                    talk("Isn't he handsome?")
                    break#
                else:
                    talk(talk_bad())
                    color_html('red',talk_bad())
                    talk(talk_bad())
            except:
                color_html('red',talk_bad())
                talk(talk_bad())
                driver= input("Perhaps you should type in your intended driver: ")
                break
except KeyError:
    color_html("red","Are you sure this is one of the suggested drivers? Please input the suggested drivern name again.")

#def web
while True:
    try:
        driver_web = web_request (driver)
        datalist = pd.read_html(driver_web) 
        f1Data = pd.DataFrame() 
        #append to list and drop fastest lap and one another column
        f1Data = f1Data.append(datalist[0]).drop([0,3,6, 8,9], axis=1).dropna()
        #print(driver_web)

        #filter year funciton
        #how can i shrink these lines? groupby? 
        f1Data2007 = f1Data[f1Data[1].str[:4]=='2007'] 
        f1Data2008 = f1Data[f1Data[1].str[:4]=='2008'] 
        f1Data2009 = f1Data[f1Data[1].str[:4]=='2009'] 
        f1Data2010 = f1Data[f1Data[1].str[:4]=='2010']
        f1Data2011 = f1Data[f1Data[1].str[:4]=='2011']
        f1Data2012 = f1Data[f1Data[1].str[:4]=='2012']
        f1Data2013 = f1Data[f1Data[1].str[:4]=='2013']
        f1Data2014 = f1Data[f1Data[1].str[:4]=='2014']
        f1Data2015 = f1Data[f1Data[1].str[:4]=='2015']
        f1Data2016 = f1Data[f1Data[1].str[:4]=='2016']
        f1Data2017 = f1Data[f1Data[1].str[:4]=='2017']
#list dictionary key is year, each year correspond data year 
        f1Data_list = [f1Data2007,f1Data2008,f1Data2009,f1Data2010,
                       f1Data2011,f1Data2012,f1Data2013,f1Data2014,f1Data2015,f1Data2016,f1Data2017]
        #while true 

        total2007 = 0
        total2008 = 0
        total2009 = 0
        total2010 = 0
        for items in f1Data2007[7]:
            total2007 = total2007 + float(items)
        for items in f1Data2008[7]:
            total2008 = total2008 + float(items)
        for items in f1Data2010[7]:
            total2009 = total2009 + float(items)
        for items in f1Data2010[7]:
            total2010 = total2010 + float(items)
        total2011 = 0
        for items in f1Data2011[7]:
            total2011 = total2011 + float(items)
        total2012 = 0
        for items in f1Data2012[7]:
            total2012 = total2012 + float(items)
        total2013 =0
        for items in f1Data2013[7]:
            total2013 = total2013 + float(items)
        total2014 = 0
        for items in f1Data2014[7]:
            total2014 = total2014 + float(items)
        total2015 = 0
        for items in f1Data2015[7]:
            total2015 = total2015 + float(items)
        total2016 = 0
        for items in f1Data2016[7]:
            total2016 = total2016 + float(items)
        total2017 = 0
        for items in f1Data2017[7]:
            total2017 = total2017 + float(items)
        total_points_calulator ()
        #sum up the points for each year
        #plot team graph



        #plot driver team graph

        #plot driver score graph
        plot_graph(driver)
        color_html('blue',"Here are the  points %s scored each year from year 2007 to 2017. "%(driver))
        talk("Here are the  points %s scored each year from year 2007 to 2017. "%(driver))
        
        break


    except KeyError:
        color_html('red',"Your driver is either:1)not in the list 2)has their name spelled wrong. Please try again :)")
        talk("Your driver is either:1)not in the list 2)has their name spelled wrong. Please try again")
        driver = input("Perhaps you should type in your input: ")
        break
    #not sure why prints twice
#f1DataMap = f1Data.append(datalist[0]).drop([0,3,6, 8,9,4,7], axis=1).dropna()
#f1DataMap = f1DataMap[f1DataMap[1].str[:4]=='2017']
#f1DataMap = f1DataMap[f1DataMap[5] == '2'] #or f1DataMap[f1DataMap[5] == '2']
#f1DataMap = f1DataMap[f1DataMap[5] == '2']
#f1DataMap
#gradient plotting?

color_html('blue',"Which year do you want to look at specifically? Please choose from range 2007 to 2017: " )
talk("Which year do you want to look at specifically? Please choose from range 2007 to 2017: " )
color_html("blue","Enter the year you think %s is the best in: " %(driver))


count = 0
while True:
    try: 
        color_html('Aquamarine',"Your FormulaSmart Assistant is listening...")
        podium_year = int(speak())
        #while podium_year < 2007 and podium_year > 2017:
        if podium_year > 2007 and podium_year < 2018:
            break
        else:    
            color_html("red",'Please input a valid year')
    except:
        color_html("red",'Please input a valid year')
        podium_year = input("Perhaps you should type in a year: ")
        break
    
    

f1DataMap = f1Data[f1Data[1].str[:4]==str(podium_year)]
f1DataMap_first = f1DataMap[f1DataMap[5]=='1']
f1DataMap_second = f1DataMap[f1DataMap[5]=='2']
f1DataMap_third = f1DataMap[f1DataMap[5]=='3']

#talk("Here is a map of %s's first, second, and third place"%(driver))
#def find_city (driver)
city_first = []#cities that the driver came first
color_html("lightblue","Here are the locations %s finished first in year %s!"%(driver,podium_year))
talk("Here are the locations %s finished first in year %s!"%(driver,podium_year))
for city in f1DataMap_first[2]:
    city_first.append(city)
    color_html("lightblue",city)



    
city_second = [] #cities the driver came second
color_html("darkblue","Here are the locations %s finished second in year %s!"%(driver,podium_year))
talk("Here are the locations %s finished second in year %s!"%(driver,podium_year))
for city in f1DataMap_second[2]:
    city_second.append(city)
    color_html("darkblue",city)


city_third = [] #city driver came third
color_html("CadetBlue","Last but not least, here are the locations %s finished third in year %s!"%(driver, podium_year))
talk(" Last but not least, here are the locations %s finished third! in year %s!"%(driver,podium_year))
for city in f1DataMap_third[2]:
    city_third.append(city)
    color_html("CadetBlue",city)

#return city_list

if city_first == []:
    talk("i'm so sorry your selected driver has no wins this year")
if city_second == []:
    talk("i'm so sorry your selected driver has no second place this year")

if city_third == []:
    talk("i'm so sorry your selected driver has no third place this year")



    
##more on maps
#f1DataMap = f1DataMap[f1DataMap[5]=='3']  
#f1DataMap
#map referenced from WMC 13 folium map
import warnings
warnings.filterwarnings('ignore')
colors = ['blue', 'darkblue',  'cadetblue',
             'lightblue', ]
colors = ['blue', 'darkblue',  'cadetblue',
             'lightblue', ]

print("here are the exact location of the circuit that %s got first, second, and third place."%(driver))
talk("here are the exact location of the circuit that %s got first, second, and third place."%(driver))

color_html("light blue","Do you want to look at the map where %s got first, second, and third place?"%(driver))
talk("Do you want to look at the map where %s got first, second, and third place?"%(driver))
color_html('Aquamarine',"Your FormulaSmart Assistant is listening...")
try:
    map_response = speak()
except:
    map_response = input("Perhaps you should type in your input: ")
      #  break
color_html("blue","light blue is first place, blue is second place, dark blue is third place.")
talk("light blue is first place, blue is second place, dark blue is third place.")
color_html("brown",'please wait patiently while we generate a map for you')
#talk("please wait patiently while we generate a map for you")

if map_response == 'yes':
    for city in city_first:
        #location = geolocator.geocode(city)
        location_coord = google_map(city)
        marker = folium.Marker(location=location_coord, 
                        popup="%s" % (city),
                        icon = folium.Icon(color = colors[3], icon='user')

                          )
        #map = (zoom_start=4)
        map.add_child(marker)
    #map

    #google_map(city_third[2])

    for city in city_second:
        #location = geolocator.geocode(city)
        location_coord = google_map(city)
        marker = folium.Marker(location=location_coord, 
                        popup="%s" % (city),
                        icon = folium.Icon(color = colors[1], icon='user')
                              )
        map.add_child(marker)
    for city in city_third:
        #location = geolocator.geocode(city)
        location_coord = google_map(city)
        marker = folium.Marker(location=location_coord, 
                        popup="%s" % (city),
                        icon = folium.Icon(color = colors[2], icon='user')
                          )
        map.add_child(marker)

    color_html("light blue","thank you for using FormulaSmart. Please leave any comments to my founders. They will program me in better way in the near future.  See you next time!")
    talk("it is so nice interactin with you, %s thank you for using FormulaSmart. See you next time!"%(user_name))
    color_html('darkblue',"Shutting down...")
#pick the google  api one used in class 
#shutdown code
#map_response = 'no'
if map_response == 'nah' or map_response == 'no' :
    color_html("light blue","thank you for using FormulaSmart. Please leave any comments to my founders. They will program me in better way in the near future.  See you next time!")
    talk("it is so nice interactin with you, %s thank you for using FormulaSmart. See you next time!"%(user_name))
    color_html('darkblue',"Shutting down...")
# Out:
# <span style = 'color: lightblue;'>Hi I am FormulaSmart! Your personal sport assistant. I can answer your inquiries about Formula 1!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-6dab67468c82> in <module>()
#     207 InteractiveShell.ast_node_interactivity = "all"
#     208 color_html('lightblue',"Hi I am FormulaSmart! Your personal sport assistant. I can answer your inquiries about Formula 1! ")
# --> 209 talk("Hi I am FormulaSmart! Your personal sport assistant. I can answer your inquiries about Formula 1! Here is a picture of one of my best friends!")
#     210 Image(filename='Lewis_Hamilton_2017_Malaysia_FP2.jpg')
#     211 color_html('Aquamarine',"And here are my founders! They are, from top to botom, Eldon, Ciara, and Steve.")
#
# <ipython-input-9-6dab67468c82> in talk(text)
#      39     audio_file = "hello.mp3"
#      40     tts = gTTS(text, lang="en-uk")
# ---> 41     tts.save(audio_file)
#      42     return_code = subprocess.call(["afplay", audio_file])
#      43
#
# ~/miniconda3/lib/python3.6/site-packages/gtts/tts.py in save(self, savefile)
#     109         """ Do the Web request and save to `savefile` """
#     110         with open(savefile, 'wb') as f:
# --> 111             self.write_to_fp(f)
#     112
#     113     def write_to_fp(self, fp):
#
# ~/miniconda3/lib/python3.6/site-packages/gtts/tts.py in write_to_fp(self, fp)
#     122                         'client' : 'tw-ob',
#     123                         'textlen' : self._len(part),
# --> 124                         'tk' : self.token.calculate_token(part)}
#     125             headers = {
#     126                 "Referer" : "http://translate.google.com/",
#
# ~/miniconda3/lib/python3.6/site-packages/gtts_token/gtts_token.py in calculate_token(self, text, seed)
#      26
#      27         if seed is None:
# ---> 28             seed = self._get_token_key()
#      29
#      30         [first_seed, second_seed] = seed.split(".")
#
# ~/miniconda3/lib/python3.6/site-packages/gtts_token/gtts_token.py in _get_token_key(self)
#      59         line = response.text.split('\n')[-1]
#      60
# ---> 61         tkk_expr = re.search(".*?(TKK=.*?;)W.*?", line).group(1)
#      62         a = re.search("a\\\\x3d(-?\d+);", tkk_expr).group(1)
#      63         b = re.search("b\\\\x3d(-?\d+);", tkk_expr).group(1)
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
#modules and functions
#have to twice to get the code running, no idea why

#import modules
import pandas as pd
import wikipedia
import numpy as np
from IPython.display import display # this isnot the issue that's displaying all the map pins 
import dateutil #useless, convert date to a date
import matplotlib.pyplot as plt
import folium
import random 
from geopy.geocoders import Nominatim #always create timeout error -v- idky
geolocator = Nominatim()
import warnings
warnings.filterwarnings('ignore')
from gtts import gTTS #google text to speech
from time import sleep #hault the tts fx
import time
import pyglet #speech to text 
import os    
import subprocess 
from gtts import gTTS
map = folium.Map(zoom_start=3)
import speech_recognition as sr
from IPython.display import display, HTML
import matplotlib.pyplot as plt; plt.rcdefaults()
import webbrowser
from IPython.display import Image
from IPython.core.interactiveshell import InteractiveShell #this might be the problem 
InteractiveShell.ast_node_interactivity = "all"
import json
import requests



###functions###
#text to audio
def talk(text):
    audio_file = "hello.mp3"
    tts = gTTS(text, lang="en-uk")
    tts.save(audio_file)
    return_code = subprocess.call(["afplay", audio_file])

# %%
 audio_file = "hello.mp3"
tts = gTTS(text, lang="en-uk")
tts.save(audio_file)
return_code = subprocess.call(["afplay", audio_file])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-bf991d279da6> in <module>()
#       1 audio_file = "hello.mp3"
#       2 tts = gTTS(text, lang="en-uk")
# ----> 3 tts.save(audio_file)
#       4 return_code = subprocess.call(["afplay", audio_file])
#
# ~/miniconda3/lib/python3.6/site-packages/gtts/tts.py in save(self, savefile)
#     109         """ Do the Web request and save to `savefile` """
#     110         with open(savefile, 'wb') as f:
# --> 111             self.write_to_fp(f)
#     112
#     113     def write_to_fp(self, fp):
#
# ~/miniconda3/lib/python3.6/site-packages/gtts/tts.py in write_to_fp(self, fp)
#     122                         'client' : 'tw-ob',
#     123                         'textlen' : self._len(part),
# --> 124                         'tk' : self.token.calculate_token(part)}
#     125             headers = {
#     126                 "Referer" : "http://translate.google.com/",
#
# ~/miniconda3/lib/python3.6/site-packages/gtts_token/gtts_token.py in calculate_token(self, text, seed)
#      26
#      27         if seed is None:
# ---> 28             seed = self._get_token_key()
#      29
#      30         [first_seed, second_seed] = seed.split(".")
#
# ~/miniconda3/lib/python3.6/site-packages/gtts_token/gtts_token.py in _get_token_key(self)
#      59         line = response.text.split('\n')[-1]
#      60
# ---> 61         tkk_expr = re.search(".*?(TKK=.*?;)W.*?", line).group(1)
#      62         a = re.search("a\\\\x3d(-?\d+);", tkk_expr).group(1)
#      63         b = re.search("b\\\\x3d(-?\d+);", tkk_expr).group(1)
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
text = input('text: ')
talk(text)
#functions
# Out:
# text: sdfg
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-65ecbf1618c2> in <module>()
#       1 text = input('text: ')
# ----> 2 talk(text)
#       3 #functions
#
# <ipython-input-11-5e526add65d3> in talk(text)
#      39     audio_file = "hello.mp3"
#      40     tts = gTTS(text, lang="en-uk")
# ---> 41     tts.save(audio_file)
#      42     return_code = subprocess.call(["afplay", audio_file])
#      43
#
# ~/miniconda3/lib/python3.6/site-packages/gtts/tts.py in save(self, savefile)
#     109         """ Do the Web request and save to `savefile` """
#     110         with open(savefile, 'wb') as f:
# --> 111             self.write_to_fp(f)
#     112
#     113     def write_to_fp(self, fp):
#
# ~/miniconda3/lib/python3.6/site-packages/gtts/tts.py in write_to_fp(self, fp)
#     122                         'client' : 'tw-ob',
#     123                         'textlen' : self._len(part),
# --> 124                         'tk' : self.token.calculate_token(part)}
#     125             headers = {
#     126                 "Referer" : "http://translate.google.com/",
#
# ~/miniconda3/lib/python3.6/site-packages/gtts_token/gtts_token.py in calculate_token(self, text, seed)
#      26
#      27         if seed is None:
# ---> 28             seed = self._get_token_key()
#      29
#      30         [first_seed, second_seed] = seed.split(".")
#
# ~/miniconda3/lib/python3.6/site-packages/gtts_token/gtts_token.py in _get_token_key(self)
#      59         line = response.text.split('\n')[-1]
#      60
# ---> 61         tkk_expr = re.search(".*?(TKK=.*?;)W.*?", line).group(1)
#      62         a = re.search("a\\\\x3d(-?\d+);", tkk_expr).group(1)
#      63         b = re.search("b\\\\x3d(-?\d+);", tkk_expr).group(1)
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
from gtts import gTTS
blabla = ("Spoken text")
tts = gTTS(text=blabla, lang='en')
tts.save(audio_file)
return_code = subprocess.call(["afplay", audio_file])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-5c4bce4e3317> in <module>()
#       2 blabla = ("Spoken text")
#       3 tts = gTTS(text=blabla, lang='en')
# ----> 4 tts.save(audio_file)
#       5 return_code = subprocess.call(["afplay", audio_file])
#
# ~/miniconda3/lib/python3.6/site-packages/gtts/tts.py in save(self, savefile)
#     109         """ Do the Web request and save to `savefile` """
#     110         with open(savefile, 'wb') as f:
# --> 111             self.write_to_fp(f)
#     112
#     113     def write_to_fp(self, fp):
#
# ~/miniconda3/lib/python3.6/site-packages/gtts/tts.py in write_to_fp(self, fp)
#     122                         'client' : 'tw-ob',
#     123                         'textlen' : self._len(part),
# --> 124                         'tk' : self.token.calculate_token(part)}
#     125             headers = {
#     126                 "Referer" : "http://translate.google.com/",
#
# ~/miniconda3/lib/python3.6/site-packages/gtts_token/gtts_token.py in calculate_token(self, text, seed)
#      26
#      27         if seed is None:
# ---> 28             seed = self._get_token_key()
#      29
#      30         [first_seed, second_seed] = seed.split(".")
#
# ~/miniconda3/lib/python3.6/site-packages/gtts_token/gtts_token.py in _get_token_key(self)
#      59         line = response.text.split('\n')[-1]
#      60
# ---> 61         tkk_expr = re.search(".*?(TKK=.*?;)W.*?", line).group(1)
#      62         a = re.search("a\\\\x3d(-?\d+);", tkk_expr).group(1)
#      63         b = re.search("b\\\\x3d(-?\d+);", tkk_expr).group(1)
#
# AttributeError: 'NoneType' object has no attribute 'group'
